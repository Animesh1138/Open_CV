# %%
')
# Out:
# Drive already mounted at /content/sample_data/x1.png; to attempt to forcibly remount, call drive.mount("/content/sample_data/x1.png", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6557cde2194a> in <cell line: 4>()
#       2
#       3 img = drive.mount('/content/sample_data/x1.png')
# ----> 4 x1.png
#
# NameError: name 'x1' is not defined
